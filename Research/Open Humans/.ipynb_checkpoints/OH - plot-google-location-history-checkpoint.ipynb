# %% [markdown]
# # Analyzing your Google Location History in R
# This notebook requires you to use the [*Google Location History* upload](https://oh-googlelocationhistory.herokuapp.com/) to get your GPS data into Open Humans.
#
# This notebook then uses the GPS data to plot your personal movement history on different maps on different scales.
#
# For a start let's load our required packages. To load the *JSON* we are using `rjson`, which needs to be installed with `install.packages` in the first step:

# %%
#install.packages('rjson')
library(httr)
#library("rjson")
library(jsonlite)
library(ggplot2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-038953f4f11d> in <module>
#       1 #install.packages('rjson')
# ----> 2 library(httr)
#       3 #library("rjson")
#       4 library(jsonlite)
#       5 library(ggplot2)
#
# NameError: name 'library' is not defined

# %% [markdown]
# With that out of the way we can access our *Google Location History* data from our Open Humans account:

# %%
# access_token <- Sys.getenv("OH_ACCESS_TOKEN")
# url <- paste("https://www.openhumans.org/api/direct-sharing/project/exchange-member/?access_token=",access_token,sep="")
# resp <- GET(url)
# user <- content(resp, "parsed")

# for (data_source in user$data){
#     if (data_source$source == "direct-sharing-182"){
#          gps_data_url <- data_source$download_url
#     }
# }

# temp <- tempfile()
# download.file(gps_data_url,temp,method='wget')
# json_data <- fromJSON(txt=temp)

# %%
import json

with open("/Users/aditya/Google Drive (as11919@nyu.edu)/Syncing with Mac/My Data Analysis/All Data/Takeout (google data +fitbit exports)/google location data for OH notebook/Location History/Location History.json") as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'locations': [{'timestampMs': '1377454176617',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377454094149',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377454236695',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377454296675',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377454357467',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377454417773',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377454477519',
#    'latitudeE7': 185747726,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377454537799',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377454597107',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377454667654',
#    'latitudeE7': 185746984,
#    'longitudeE7': 738935362,
#    'accuracy': 36,
#    'activity': [{'timestampMs': '1377454689557',
#      'activity': [{'type': 'STILL', 'confidence': 77},
#       {'type': 'IN_VEHICLE', 'confidence': 15},
#       {'type': 'UNKNOWN', 'confidence': 7}]}]},
#   {'timestampMs': '1377454727535',
#    'latitudeE7': 185746958,
#    'longitudeE7': 738935429,
#    'accuracy': 30},
#   {'timestampMs': '1377454786763',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377454896380',
#    'latitudeE7': 185746952,
#    'longitudeE7': 738935373,
#    'accuracy': 33},
#   {'timestampMs': '1377455051741',
#    'latitudeE7': 185747048,
#    'longitudeE7': 738935325,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377455077560',
#      'activity': [{'type': 'STILL', 'confidence': 58},
#       {'type': 'IN_VEHICLE', 'confidence': 23},
#       {'type': 'UNKNOWN', 'confidence': 18}]}]},
#   {'timestampMs': '1377455103746',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377455162395',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377455157240',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377455228186',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377455289135',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377455344865',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377455336912',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377455348676',
#    'latitudeE7': 185747110,
#    'longitudeE7': 738935228,
#    'accuracy': 21},
#   {'timestampMs': '1377455416996',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377455492606',
#    'latitudeE7': 185747021,
#    'longitudeE7': 738935326,
#    'accuracy': 30},
#   {'timestampMs': '1377455536775',
#    'latitudeE7': 185746765,
#    'longitudeE7': 738935573,
#    'accuracy': 36,
#    'activity': [{'timestampMs': '1377455564133',
#      'activity': [{'type': 'UNKNOWN', 'confidence': 81},
#       {'type': 'IN_VEHICLE', 'confidence': 7},
#       {'type': 'STILL', 'confidence': 7},
#       {'type': 'ON_FOOT', 'confidence': 3}]}]},
#   {'timestampMs': '1377455594218',
#    'latitudeE7': 185746753,
#    'longitudeE7': 738935601,
#    'accuracy': 30},
#   {'timestampMs': '1377455653322',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935603,
#    'accuracy': 33,
#    'activity': [{'timestampMs': '1377455640086',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377455713101',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377455773205',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377455833388',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377455893204',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377455953215',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377456013215',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377456073431',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377456133436',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377456193707',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377456253519',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377456313530',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935587,
#    'accuracy': 30},
#   {'timestampMs': '1377456373561',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456433580',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456493604',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456553590',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456613603',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377456673652',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456733680',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377456793701',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377456853710',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456913730',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377456973752',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377457033750',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377457093766',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457153777',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457213819',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377457273848',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457333863',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457393891',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457453901',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377457513921',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377457573918',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457633927',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457693949',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377457754012',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457814032',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377457817331',
#    'latitudeE7': 185747005,
#    'longitudeE7': 738935153,
#    'accuracy': 21},
#   {'timestampMs': '1377457877419',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377457937396',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377457997427',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458057431',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458117450',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377458177469',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458237492',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458297490',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458357498',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377458417513',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935870,
#    'accuracy': 30},
#   {'timestampMs': '1377458477715',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458537751',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458597739',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377458657734',
#    'latitudeE7': 185747037,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377458717784',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377458777828',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458838665',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377458897922',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377458957972',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459017965',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459077982',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459138009',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459198009',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459258015',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377459318037',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459378092',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377459438098',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459498116',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377459558133',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377459618144',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377459678172',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459738184',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459798175',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377459858213',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377459918199',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377459978253',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460038274',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460098298',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377460158326',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377460218325',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460278343',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460338347',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377460398374',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377460458365',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460518367',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377460578385',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377460638452',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377460698489',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377460758492',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377460818504',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377460878525',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377460938541',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377460998539',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377461058543',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377461118560',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461178628',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461238674',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377461298675',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377461358676',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377461418692',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377461421421',
#    'latitudeE7': 185746903,
#    'longitudeE7': 738935776,
#    'accuracy': 21},
#   {'timestampMs': '1377461481465',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377461541465',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461601490',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461661501',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461721497',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461781509',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377461842705',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377461901519',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377461961578',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377462021587',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462081620',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462141639',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462201657',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462261661',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462321676',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377462381690',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462441682',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462501746',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462561769',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462621788',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462681798',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462741820',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462801829',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377462861846',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377462921880',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377462981890',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463041918',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463101935',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463161950',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463222044',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377463282033',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463342043',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463402045',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463462063',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463522070',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377463582130',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463642169',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463702165',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463762194',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463822206',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377463882226',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377463942213',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464002236',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377464062241',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377464122296',
#    'latitudeE7': 185746632,
#    'longitudeE7': 738935729,
#    'accuracy': 30},
#   {'timestampMs': '1377464182330',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377464242335',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464302370',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464362384',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464422374',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377464482396',
#    'latitudeE7': 185746465,
#    'longitudeE7': 738935913,
#    'accuracy': 21},
#   {'timestampMs': '1377464542402',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464602494',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464662582',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377464722520',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464782523',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464842532',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377464902546',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377464962546',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465022548',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465026633',
#    'latitudeE7': 185747112,
#    'longitudeE7': 738935417,
#    'accuracy': 21,
#    'activity': [{'timestampMs': '1377461136620',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377465086742',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377465146726',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465206749',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465266769',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465326777',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377465386788',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377465446807',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465506878',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465567029',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465627049',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465687099',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465747120',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465807133',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465867150',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465927161',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377465987192',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466047172',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466107227',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466167214',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377466227208',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466287272',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466347315',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466407330',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377466467338',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466527347',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466587440',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377466647369',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377466707367',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466767429',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377466827447',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377466887459',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377466947495',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467007517',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377467067534',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377467127579',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467187600',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467247628',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377467307629',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467367650',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467427679',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467487671',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467547680',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467607699',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467667691',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467727714',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377467787754',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377467847781',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377467907802',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377467967824',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377468027839',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377468087849',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468147870',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468207869',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468267870',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468327877',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377468387870',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468447951',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377468507973',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377468568022',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468628018',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377468630891',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935343,
#    'accuracy': 21},
#   {'timestampMs': '1377468690896',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468750952',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377468810980',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377468871058',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468931007',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377468991017',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377469051036',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377469111052',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377469171048',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377469231062',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377469291144',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469351132',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469411163',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469471190',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377469531196',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377469591224',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377469651214',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469711237',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377469771236',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377469831349',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469891301',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377469951335',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470011369',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470071371',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377470131392',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377470191388',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470251454',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377470311480',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470371554',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470431505',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470491545',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470551532',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470611541',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470671569',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470731553',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377470791635',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377470851643',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377470911652',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377470971667',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377471031701',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471091700',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471151702',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471211723',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471271737',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377471331781',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471391808',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471451825',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377471511842',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377471571860',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471631869',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471691874',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471751893',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377471811891',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471871950',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377471931979',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377471991994',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472052016',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472112029',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472172028',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377472232036',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472236494',
#    'latitudeE7': 185746840,
#    'longitudeE7': 738935228,
#    'accuracy': 21},
#   {'timestampMs': '1377472296577',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377472356547',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377472416576',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472476643',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935587,
#    'accuracy': 30},
#   {'timestampMs': '1377472536583',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377472596591',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377472656612',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472716740',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472776667',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377472836686',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377472896708',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377472956725',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377473016758',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377473076753',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377473136793',
#    'latitudeE7': 185747037,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473196777',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377473256783',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377473316844',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473376854',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473436884',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377473496905',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473556900',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473616924',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377473676955',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377473736944',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473797101',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473857036',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473917066',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377473977064',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377474037082',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377474097087',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377474157093',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738936251,
#    'accuracy': 30},
#   {'timestampMs': '1377474217181',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377474257884',
#    'latitudeE7': 185746788,
#    'longitudeE7': 738935609,
#    'accuracy': 30},
#   {'timestampMs': '1377474317892',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935528,
#    'accuracy': 30},
#   {'timestampMs': '1377474377900',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377474437913',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377474497959',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377474557979',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377474618013',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377474678010',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377474738024',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377474798047',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377474858125',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377474918060',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377474978068',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475038121',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475098143',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475158139',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475218164',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377475278180',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475338395',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475398371',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377475458418',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475518431',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475578434',
#    'latitudeE7': 185746768,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475638444',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377475698456',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377475758465',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935871,
#    'accuracy': 30},
#   {'timestampMs': '1377475818474',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475878487',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377475881654',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 21},
#   {'timestampMs': '1377475941669',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476001728',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476061753',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476121788',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476181861',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476241888',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476301910',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476361919',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476421949',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377476481938',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476541948',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476601971',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476662018',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476722049',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476782059',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476842069',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476902081',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377476962126',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477022108',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477082112',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377477142130',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477202136',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377477262191',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377477322220',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477382267',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477442258',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477502269',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477562263',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377477622287',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377477682305',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477742298',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377477802300',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377477862648',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377477922526',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377477982429',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478042442',
#    'latitudeE7': 185746496,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377478102442',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935152,
#    'accuracy': 30},
#   {'timestampMs': '1377478162485',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377478222479',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377478282467',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478342536',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377478402546',
#    'latitudeE7': 185746657,
#    'longitudeE7': 738935470,
#    'accuracy': 30},
#   {'timestampMs': '1377478462568',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478522593',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478582609',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935870,
#    'accuracy': 30},
#   {'timestampMs': '1377478642610',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377478702644',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478762625',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478822639',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478882711',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377478942716',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
# ...
#      'activity': [{'type': 'UNKNOWN', 'confidence': 73},
#       {'type': 'IN_VEHICLE', 'confidence': 11},
#       {'type': 'ON_BICYCLE', 'confidence': 11},
#       {'type': 'ON_FOOT', 'confidence': 3}]}]},
#   {'timestampMs': '1377530183160',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377530197474',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377530243137',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530303201',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530363498',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530423226',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377530426238',
#      'activity': [{'type': 'STILL', 'confidence': 76},
#       {'type': 'UNKNOWN', 'confidence': 23}]}]},
#   {'timestampMs': '1377530483273',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530543751',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530603294',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377530615035',
#      'activity': [{'type': 'UNKNOWN', 'confidence': 46},
#       {'type': 'STILL', 'confidence': 27},
#       {'type': 'IN_VEHICLE', 'confidence': 22},
#       {'type': 'ON_FOOT', 'confidence': 3}]}]},
#   {'timestampMs': '1377530663297',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530723291',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377530738343',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377530783578',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377530843490',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377530904214',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377530964247',
#    'latitudeE7': 185747320,
#    'longitudeE7': 738935011,
#    'accuracy': 30},
#   {'timestampMs': '1377531024378',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531084300',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377531087190',
#      'activity': [{'type': 'UNKNOWN', 'confidence': 71},
#       {'type': 'STILL', 'confidence': 15},
#       {'type': 'IN_VEHICLE', 'confidence': 11},
#       {'type': 'ON_FOOT', 'confidence': 1}]}]},
#   {'timestampMs': '1377531145752',
#    'latitudeE7': 185747726,
#    'longitudeE7': 738934584,
#    'accuracy': 30},
#   {'timestampMs': '1377531204714',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934869,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377531199311',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377531265660',
#    'latitudeE7': 185746767,
#    'longitudeE7': 738935586,
#    'accuracy': 30},
#   {'timestampMs': '1377531384957',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377531457564',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531518244',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531578289',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531638285',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531698299',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377531818892',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934726,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377531837543',
#      'activity': [{'type': 'UNKNOWN', 'confidence': 61},
#       {'type': 'IN_VEHICLE', 'confidence': 21},
#       {'type': 'ON_FOOT', 'confidence': 13},
#       {'type': 'ON_BICYCLE', 'confidence': 3}]}]},
#   {'timestampMs': '1377531877555',
#    'latitudeE7': 185748232,
#    'longitudeE7': 738934057,
#    'accuracy': 20},
#   {'timestampMs': '1377531937687',
#    'latitudeE7': 185748232,
#    'longitudeE7': 738934057,
#    'accuracy': 20},
#   {'timestampMs': '1377532058033',
#    'latitudeE7': 185748052,
#    'longitudeE7': 738934057,
#    'accuracy': 20},
#   {'timestampMs': '1377532178884',
#    'latitudeE7': 185748052,
#    'longitudeE7': 738934247,
#    'accuracy': 20},
#   {'timestampMs': '1377532238922',
#    'latitudeE7': 185747590,
#    'longitudeE7': 738934726,
#    'accuracy': 30},
#   {'timestampMs': '1377532298905',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934727,
#    'accuracy': 30},
#   {'timestampMs': '1377532423900',
#    'latitudeE7': 185747545,
#    'longitudeE7': 738934646,
#    'accuracy': 30},
#   {'timestampMs': '1377532478910',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934727,
#    'accuracy': 30},
#   {'timestampMs': '1377532539769',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377532599763',
#    'latitudeE7': 185747726,
#    'longitudeE7': 738934206,
#    'accuracy': 30},
#   {'timestampMs': '1377532659740',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377532719822',
#    'latitudeE7': 185747591,
#    'longitudeE7': 738934726,
#    'accuracy': 30},
#   {'timestampMs': '1377532779942',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377532839804',
#    'latitudeE7': 185747591,
#    'longitudeE7': 738934726,
#    'accuracy': 30},
#   {'timestampMs': '1377532857167',
#    'latitudeE7': 185747522,
#    'longitudeE7': 738934939,
#    'accuracy': 21,
#    'activity': [{'timestampMs': '1377532866810',
#      'activity': [{'type': 'TILTING', 'confidence': 100}]}]},
#   {'timestampMs': '1377532917180',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377532977463',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377533037435',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377533096602',
#    'latitudeE7': 185747365,
#    'longitudeE7': 738934868,
#    'accuracy': 30},
#   {'timestampMs': '1377533157481',
#    'latitudeE7': 185747320,
#    'longitudeE7': 738935199,
#    'accuracy': 30},
#   {'timestampMs': '1377533216697',
#    'latitudeE7': 185747320,
#    'longitudeE7': 738935199,
#    'accuracy': 30},
#   {'timestampMs': '1377533277571',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377533338067',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377533397571',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377533457665',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377533517646',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377533577684',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30,
#    'activity': [{'timestampMs': '1377533574146',
#      'activity': [{'type': 'STILL', 'confidence': 55},
#       {'type': 'IN_VEHICLE', 'confidence': 32},
#       {'type': 'UNKNOWN', 'confidence': 11}]}]},
#   {'timestampMs': '1377533641079',
#    'latitudeE7': 185747154,
#    'longitudeE7': 738935202,
#    'accuracy': 37},
#   {'timestampMs': '1377533699685',
#    'latitudeE7': 185746931,
#    'longitudeE7': 738935434,
#    'accuracy': 30},
#   {'timestampMs': '1377533759632',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377533819674',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377533879648',
#    'latitudeE7': 185747038,
#    'longitudeE7': 738935302,
#    'accuracy': 30},
#   {'timestampMs': '1377533939655',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377534059705',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377534179810',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377534239718',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377534299728',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377534419794',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377534539831',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377534599846',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377534659852',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377534720495',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377534780626',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377534840644',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377534900646',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377534960656',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535020687',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377535080802',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535140699',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535200845',
#    'latitudeE7': 185747455,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377535260857',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377535320855',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535380857',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377535441799',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377535501800',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377535622660',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377535682560',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535802821',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535862789',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377535983473',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536043496',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536103474',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536223604',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536283656',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536343658',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536403678',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536463768',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536472310',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935343,
#    'accuracy': 21},
#   {'timestampMs': '1377536532362',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536592358',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536652367',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536712374',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536772449',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536832460',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377536892497',
#    'latitudeE7': 185746824,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377536952487',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537012517',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537072658',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537132650',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537192664',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377537253886',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377537313809',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537373800',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537433811',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537493802',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537553835',
#    'latitudeE7': 185747183,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537673869',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537793964',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377537853917',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537913906',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377537973942',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377538033978',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538093940',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377538154014',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538213568',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538274375',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538334553',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538394682',
#    'latitudeE7': 185747456,
#    'longitudeE7': 738934869,
#    'accuracy': 30},
#   {'timestampMs': '1377538454726',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   {'timestampMs': '1377538514780',
#    'latitudeE7': 185747185,
#    'longitudeE7': 738935153,
#    'accuracy': 30},
#   {'timestampMs': '1377538574746',
#    'latitudeE7': 185746825,
#    'longitudeE7': 738935532,
#    'accuracy': 30},
#   ...]}

# %% [markdown]
# ## Getting started with the data processing
# Now that we have our fitbit data stored in `json_data` we can start to work with that data. Much of this notebook is [adapted code from Shirin Glander's excellent blogpost](https://shiring.github.io/maps/2016/12/30/Standortverlauf_post).
#
# Let's read the location data in to the `loc` variable and properly parse the timestamps of when we have been at a place and convert the E7 formatted coordinates to regular coordinates:

# %%
# extracting the locations dataframe
loc = json_data$locations

# converting time column from posix milliseconds into a readable time scale
loc$time = as.POSIXct(as.numeric(json_data$locations$timestampMs)/1000, origin = "1970-01-01")

# converting longitude and latitude from E7 to GPS coordinates
loc$lat = loc$latitudeE7 / 1e7
loc$lon = loc$longitudeE7 / 1e7

# %% [markdown]
# Now we can look at how our data looks like:

# %%
tail(loc)
# Out:
# $time
# POSIXct of length 0
#
# $lat
# numeric(0)
#
# $lon
# numeric(0)

# %% [markdown]
# ## Analyzing the data
# Now that we have collected and formatted the data we can start analyzing it!
#
# ### How much data does Google have?
# Let's start off to see how much data Google has about my location? After some more data processing we want to plot:
#
# - How many data points does Google have
#     - per Day?
#     - per Month?
#     - per Year?

# %%
install.packages('ggmap')
library(lubridate)
library(zoo)

loc$date <- as.Date(loc$time, '%Y/%m/%d')
loc$year <- year(loc$date)
loc$month_year <- as.yearmon(loc$date)

points_p_day <- data.frame(table(loc$date), group = "day")
points_p_month <- data.frame(table(loc$month_year), group = "month")
points_p_year <- data.frame(table(loc$year), group = "year")
# set up plotting theme
library(ggplot2)
library(ggmap)

my_theme <- function(base_size = 12, base_family = "sans"){
  theme_grey(base_size = base_size, base_family = base_family) +
  theme(
    axis.text = element_text(size = 12),
    axis.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
    axis.title = element_text(size = 14),
    panel.grid.major = element_line(color = "grey"),
    panel.grid.minor = element_blank(),
    panel.background = element_rect(fill = "aliceblue"),
    strip.background = element_rect(fill = "lightgrey", color = "grey", size = 1),
    strip.text = element_text(face = "bold", size = 12, color = "navy"),
    legend.position = "right",
    legend.background = element_blank(),
    panel.margin = unit(.5, "lines"),
    panel.border = element_rect(color = "grey", fill = NA, size = 0.5)
  )
}

points <- rbind(points_p_day[, -1], points_p_month[, -1], points_p_year[, -1])

ggplot(points, aes(x = group, y = Freq)) + 
  geom_point(position = position_jitter(width = 0.2), alpha = 0.3) + 
  geom_boxplot(aes(color = group), size = 1, outlier.colour = NA) + 
  facet_grid(group ~ ., scales = "free") + my_theme() +
  theme(
    legend.position = "none",
    strip.placement = "outside",
    strip.background = element_blank(),
    strip.text = element_blank(),
    axis.text.x = element_text(angle = 0, vjust = 0.5, hjust = 0.5)
  ) +
  labs(
    x = "",
    y = "Number of data points",
    title = "How many data points did Google collect about me?",
    subtitle = "Number of data points per day, month and year"
  )
# Out:
# also installing the dependencies ‘sp’, ‘RgoogleMaps’, ‘png’, ‘rjson’, ‘jpeg’

# %% [markdown]
# There's some variation in the amount of data Google recorded for each time unit, but nevertheless it seems to come out at around 50 data points per day on average. This probably also depends on how much we travel, the more we are traveling, the more data can be collected.
#
# ### How accurate is the data Google stores?
# Google gives an estimation on how accurate the data is it recorded about our location. Let's plot how accurate that data is:

# %%
accuracy <- data.frame(accuracy = loc$accuracy, group = ifelse(loc$accuracy < 800, "high", ifelse(loc$accuracy < 5000, "middle", "low")))

accuracy$group <- factor(accuracy$group, levels = c("high", "middle", "low"))

ggplot(accuracy, aes(x = accuracy, fill = group)) + 
  geom_histogram() + 
  facet_grid(group ~ ., scales="free") + 
  my_theme() +
  theme(
    legend.position = "none",
    strip.placement = "outside",
    strip.background = element_blank(),
    axis.text.x = element_text(angle = 0, vjust = 0.5, hjust = 0.5)
  ) +
  labs(
    x = "Accuracy in metres",
    y = "Count",
    title = "How accurate is the location data?",
    subtitle = "Histogram of accuracy of location points",
    caption = "\nMost data points are pretty accurate, 
but there are still many data points with a high inaccuracy.
    These were probably from areas with bad satellite reception."
  )
# Out:
# Warning message:
# “`panel.margin` is deprecated. Please use `panel.spacing` property instead”`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 482 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# Overall the accuracy of the data is pretty good and the vast majority of the data points is in the smallest error category. Then there are some outliers of data being less accurate, but that's only a small amount overall.
#
# ## Let's make some maps
#
# ### Travel around the world
# We will start by looking at a world map and plot each of the data points that Google has. This gives us a good indication of where we have been and where we might want to zoom in more:

# %%
options(warn = -1)
world <- get_map(location=c(-179,-60,179,67), source = "stamen",maptype='toner')
ggmap(world) + 
    geom_point(data = loc, aes(x=lon, y=lat), size=0.8,alpha=0.7,color='red') + 
    #stat_density_2d(geom = "point", data = loc, aes(x=lon, y=lat, size = stat(density)), n = 20, contour = FALSE)
    #geom_density_2d(bins = 300, data = loc, aes(x = lon, y = lat), alpha = 0.5, color='red') + 
  #stat_summary_2d(geom = "tile", bins = 300, data = loc, aes(x = lon, y = lat, z = accuracy), alpha = 0.5) + 
  #scale_fill_gradient(low = "blue", high = "red", guide = guide_legend(title = "Accuracy")) +
 labs(
    x = "Longitude", 
    y = "Latitude", 
    title = "Location history data points around the world")
# Out:
# Map from URL : http://tile.stamen.com/toner/2/0/0.png
# Map from URL : http://tile.stamen.com/toner/2/1/0.png
# Map from URL : http://tile.stamen.com/toner/2/2/0.png
# Map from URL : http://tile.stamen.com/toner/2/3/0.png
# Map from URL : http://tile.stamen.com/toner/2/0/1.png
# Map from URL : http://tile.stamen.com/toner/2/1/1.png
# Map from URL : http://tile.stamen.com/toner/2/2/1.png
# Map from URL : http://tile.stamen.com/toner/2/3/1.png
# Map from URL : http://tile.stamen.com/toner/2/0/2.png
# Map from URL : http://tile.stamen.com/toner/2/1/2.png
# Map from URL : http://tile.stamen.com/toner/2/2/2.png
# Map from URL : http://tile.stamen.com/toner/2/3/2.png
# plot without title

# %% [markdown]
# ### Zooming in on a place
# In my case Central Europe is more or less one huge red blob. Which makes sense given that I have been commuting between Frankfurt, Germany and Zurich, Switzerland for quite some time. So let's zoom in on this part of the world.
#
# To do so we have to define some boundary boxes through latitudes & longitudes. This can be done by the variables below. If you want to zoom in onto another part of the World: Adjust these four variables to map down to the location you are interested in. (Googling: `coordinates PLACE_OF_INTEREST` is really useful for this)

# %%
europe_boundary_west=4
europe_boundary_east=12
europe_boundary_south=45
europe_boundary_north=53.5

# %% [markdown]
# With this out of the way we can start the plotting with the code below. And to make it a bit more interesting we are not just plotting the points, but also the velocity we had at the time the data was recorded. That way we can see where we moved fast & slow.

# %%
loc_2 <- loc[which(!is.na(loc$velocity)), ]
loc_2 <- subset(loc_2, loc_2$velocity > 0)

europe <- get_map(
        location=c(europe_boundary_west,
                   europe_boundary_south,
                   europe_boundary_east,
                   europe_boundary_north), 
        source = "stamen",
        maptype='toner')
ggmap(europe) + geom_point(data = loc_2, aes(x = lon, y = lat, color = velocity), alpha = 0.1,size=0.5) + 
  theme(legend.position = "right") + 
  labs(x = "Longitude", y = "Latitude", 
       title = "Location history data points in Europe",
       subtitle = "Color scale shows velocity measured for location") +
  scale_colour_gradient(low = "blue", high = "red", guide = guide_legend(title = "Velocity"))
# Out:
# Map from URL : http://tile.stamen.com/toner/7/65/41.png
# Map from URL : http://tile.stamen.com/toner/7/66/41.png
# Map from URL : http://tile.stamen.com/toner/7/67/41.png
# Map from URL : http://tile.stamen.com/toner/7/68/41.png
# Map from URL : http://tile.stamen.com/toner/7/65/42.png
# Map from URL : http://tile.stamen.com/toner/7/66/42.png
# Map from URL : http://tile.stamen.com/toner/7/67/42.png
# Map from URL : http://tile.stamen.com/toner/7/68/42.png
# Map from URL : http://tile.stamen.com/toner/7/65/43.png
# Map from URL : http://tile.stamen.com/toner/7/66/43.png
# Map from URL : http://tile.stamen.com/toner/7/67/43.png
# Map from URL : http://tile.stamen.com/toner/7/68/43.png
# Map from URL : http://tile.stamen.com/toner/7/65/44.png
# Map from URL : http://tile.stamen.com/toner/7/66/44.png
# Map from URL : http://tile.stamen.com/toner/7/67/44.png
# Map from URL : http://tile.stamen.com/toner/7/68/44.png
# Map from URL : http://tile.stamen.com/toner/7/65/45.png
# Map from URL : http://tile.stamen.com/toner/7/66/45.png
# Map from URL : http://tile.stamen.com/toner/7/67/45.png
# Map from URL : http://tile.stamen.com/toner/7/68/45.png
# Map from URL : http://tile.stamen.com/toner/7/65/46.png
# Map from URL : http://tile.stamen.com/toner/7/66/46.png
# Map from URL : http://tile.stamen.com/toner/7/67/46.png
# Map from URL : http://tile.stamen.com/toner/7/68/46.png
# plot without title

# %% [markdown]
# The blue spots (e.g. around Frankfurt in the center of the map and around Zurich in the South) show where I moved rather slowly, i.e. on foot. Between these we can see the more purpleish connections, which are me driving on the highways.
#
# ### Enhance!
#
# Let's now zoom in some more on my movements in and around Frankfurt, where I lived for a good while. We again define our boundary box through the four cutoff-latitude/longitudes. Adjust these again if you want to zoom in on another place:

# %%
frankfurt_boundary_west=8.6
frankfurt_boundary_east=8.8
frankfurt_boundary_south=50.075
frankfurt_boundary_north=50.20

# %% [markdown]
# Now we can do the same plot as before but zoomed in at a given place:

# %%
loc_2 <- loc[which(!is.na(loc$velocity)), ]
loc_2 <- subset(loc_2, loc_2$velocity > 0)
frankfurt <- get_map(location=c(
    frankfurt_boundary_west,
    frankfurt_boundary_south,
    frankfurt_boundary_east,
    frankfurt_boundary_north), source = "stamen",maptype='toner')
ggmap(frankfurt) + geom_point(data = loc_2, aes(x = lon, y = lat, color = velocity), alpha = 0.3,size=0.7) + 
  theme(legend.position = "right") + 
  labs(x = "Longitude", y = "Latitude", 
       title = "Location history data points in Frankfurt",
       subtitle = "Color scale shows velocity measured for location") +
  scale_colour_gradient(low = "blue", high = "red", guide = guide_legend(title = "Velocity"))
# Out:
# Map from URL : http://tile.stamen.com/toner/12/2145/1385.png
# Map from URL : http://tile.stamen.com/toner/12/2146/1385.png
# Map from URL : http://tile.stamen.com/toner/12/2147/1385.png
# Map from URL : http://tile.stamen.com/toner/12/2148/1385.png
# Map from URL : http://tile.stamen.com/toner/12/2145/1386.png
# Map from URL : http://tile.stamen.com/toner/12/2146/1386.png
# Map from URL : http://tile.stamen.com/toner/12/2147/1386.png
# Map from URL : http://tile.stamen.com/toner/12/2148/1386.png
# Map from URL : http://tile.stamen.com/toner/12/2145/1387.png
# Map from URL : http://tile.stamen.com/toner/12/2146/1387.png
# Map from URL : http://tile.stamen.com/toner/12/2147/1387.png
# Map from URL : http://tile.stamen.com/toner/12/2148/1387.png
# plot without title

# %% [markdown]
# Here we can see a similar pattern. The more purplish axis from south to north is a highway - one that I'd take on my way to work regularly. The more blueish axis from west to east is one of my regular walking routes that took me from my home to downtown Frankfurt. And the blue hook to the east? One of my regular running/walking routes!
#
# ### Another Enhance!
#
# But I haven't only been living in Frankfurt. In 2017 I moved to Berkeley. Let's have a look at the map there. Again, we start with the boundaries:

# %%
berkeley_boundary_west=-122.325
berkeley_boundary_east=-122.23
berkeley_boundary_south=37.84
berkeley_boundary_north=37.89

# %%
loc_2 <- loc[which(!is.na(loc$velocity)), ]
loc_2 <- subset(loc_2, loc_2$velocity > 0)
berkeley <- get_map(location=c(berkeley_boundary_west,
                               berkeley_boundary_south,
                               berkeley_boundary_east,
                               berkeley_boundary_north), source = "stamen",maptype='toner')
ggmap(berkeley) + geom_point(data = loc_2, aes(x = lon, y = lat, color = velocity), alpha = 0.3,size=0.7) + 
  theme(legend.position = "right") + 
  labs(x = "Longitude", y = "Latitude", 
       title = "Location history data points in Berkeley",
       subtitle = "Color scale shows velocity measured for location") +
  scale_colour_gradient(low = "blue", high = "red", guide = guide_legend(title = "Velocity"))
# Out:
# Map from URL : http://tile.stamen.com/toner/13/1312/3163.png
# Map from URL : http://tile.stamen.com/toner/13/1313/3163.png
# Map from URL : http://tile.stamen.com/toner/13/1314/3163.png
# Map from URL : http://tile.stamen.com/toner/13/1312/3164.png
# Map from URL : http://tile.stamen.com/toner/13/1313/3164.png
# Map from URL : http://tile.stamen.com/toner/13/1314/3164.png
# plot without title

# %% [markdown]
# This looks different. There's much less purple and it's nearly all blue. But why? Oh, right, I didn't drive at all for
# 90% of the time living in Berkeley, so I had to do everything by walking! And it seems that I have walked all over Berkeley by now!
