# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from scipy import stats as ss
from df_correlations import *

# %%
filepath = '/Users/aditya/Google Drive (as11919@nyu.edu)/Syncing with Mac/Babel Analysis/starpi_selected_exports/showcases.csv'
test = pd.read_csv(filepath)

# %%
corr_dict, corr_dict_mirror = make_corr_dict(test, 'kendall')
# Out:
# Used Columns :  16
# Unused Columns :  17
# Unused Col Names:  ['ThumbnailType' 'accentColor' 'allCompanyProfileHidden' 'bannerHidden'
#  'callToActionAction' 'callToActionHidden' 'callToActionIcon'
#  'callToActionText' 'callToActionValue' 'companyProfileHidden'
#  'created_at' 'id' 'overview' 'overviewHidden' 'overviewSummary'
#  'overviewTitle' 'slug']

# %%
significance(corr_dict, -0.9, 0.9)
# Out:
#                  level_0              level_1    0
# 1             logoHidden         templateType    1
# 2             logoHidden               person    2
# 3             logoHidden           updated_at    3
# 4             logoHidden             isPublic    4
# 5             logoHidden     categoriesToShow    5
# 6             logoHidden          titleHidden    6
# 7             logoHidden           titleColor    7
# 8             logoHidden        hasCustomLogo    8
# 9             logoHidden      backgroundColor    9
# 10            logoHidden  hasCustomBackground   10
# 11            logoHidden           menuHidden   11
# 12            logoHidden          isPublished   12
# 13            logoHidden  isMenuAutoGenerated   13
# 14            logoHidden           customMenu   14
# 15                 title         templateType   15
# 16                 title               person   16
# 17                 title           updated_at   17
# ...

# %%
corr_table(corr_dict_mirror)
